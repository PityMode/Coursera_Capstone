# %% [markdown]
# ## Describe the data that you will be using
# For solving the problem we will be using the data provided by Coursera Capstone Course.
# This data include geolocation information about road traffic incidents, weather conditions and labels with severity of accident.
#
# Full description of the data can be found [here](https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Metadata.pdf).
